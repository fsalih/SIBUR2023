# %%
# Визуализации
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Базовые библиотеки
import math
import pathlib
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error

# %%
# Базовый ввод данных
DATA_DIR = pathlib.Path("./data")  # Откуда считываем данные
RS = 42
train = pd.read_parquet(DATA_DIR.joinpath("train.parquet"))
CAT = ["feature4"]
TARGETS = ["target0", "target1"]  # список таргетов для модели
FTS = train.filter(like="feature").columns.difference(CAT)  # Выбираем фичи для модели
train["gas"] = 0
train.loc[train.feature4=="gas2", "gas"] = 1
FTS = FTS.union(["gas"])  # список фичей для модели

# %%
X_tr, X_val, y_tr, y_val = train_test_split(train[FTS], train[TARGETS], train_size=0.5, random_state=RS)  # разбивка на трейн и тест

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2023-06-04 21:56:49.487250

# %%
def tune_function(fn, a, b):
    if fn == 'log':
        return lambda x: math.log(x-a+b)
    elif fn == 'none':
        return lambda x: x
    elif fn =='sqr':
        return lambda x: x**2/a+b
    else:
        return lambda x: x

# %%
tuner0 = {
    'feature0': {'fn': 'log', 'a': 0, 'b': 50},
    'feature1': {'fn': 'log', 'a': 15, 'b': 0},
    'feature2': {'fn': 'log', 'a': 47, 'b': 0},
    'feature3': {'fn': 'log', 'a': 0, 'b': 52},
    'feature5': {'fn': 'log', 'a': 20, 'b': 0},
    'feature6': {'fn': 'none', 'a': 0, 'b': 0},
    'feature7': {'fn': 'log', 'a': 48.44, 'b': 0},
    'feature8': {'fn': 'none', 'a': 0, 'b': 0},
    'feature9': {'fn': 'none', 'a': 0, 'b': 0},
    'feature10': {'fn': 'none', 'a': 0, 'b': 0},
    'feature11': {'fn': 'log', 'a': 0, 'b': 21},
    'feature12': {'fn': 'log', 'a': 25, 'b': 0},
    'feature13': {'fn': 'none', 'a': 0, 'b': 0},
    'feature14': {'fn': 'none', 'a': 0, 'b': 0},
    'feature15': {'fn': 'none', 'a': 0, 'b': 0},
    'feature16': {'fn': 'log', 'a': 0, 'b': 0},
    'feature17': {'fn': 'log', 'a': 0, 'b': 15},
    'feature18': {'fn': 'log', 'a': 0, 'b': 5},
    'feature19': {'fn': 'none', 'a': 0, 'b': 0},
    'feature20': {'fn': 'none', 'a': 0, 'b': 50},
    'feature21': {'fn': 'none', 'a': 0, 'b': 0},
    'feature22': {'fn': 'none', 'a': 0, 'b': 0},
    'feature23': {'fn': 'log', 'a': 32, 'b': 0},
    'feature24': {'fn': 'none', 'a': 0, 'b': 0}
}

# %%
tuner1 = {
    'feature0': {'fn': 'log', 'a': 0, 'b': 50},
    'feature1': {'fn': 'log', 'a': 15, 'b': 0},
    'feature2': {'fn': 'log', 'a': 47, 'b': 0},
    'feature3': {'fn': 'log', 'a': 0, 'b': 52},
    'feature5': {'fn': 'log', 'a': 20, 'b': 0},
    'feature6': {'fn': 'none', 'a': 0, 'b': 0},
    'feature7': {'fn': 'log', 'a': 48.44, 'b': 0},
    'feature8': {'fn': 'none', 'a': 0, 'b': 0},
    'feature9': {'fn': 'none', 'a': 0, 'b': 50},
    'feature10': {'fn': 'none', 'a': 0, 'b': 0},
    'feature11': {'fn': 'log', 'a': 0, 'b': 21},
    'feature12': {'fn': 'log', 'a': 25, 'b': 0},
    'feature13': {'fn': 'sqr', 'a': 120, 'b': 0},
    'feature14': {'fn': 'none', 'a': 0, 'b': 0},
    'feature15': {'fn': 'none', 'a': 0, 'b': 0},
    'feature16': {'fn': 'log', 'a': 0, 'b': 0},
    'feature17': {'fn': 'log', 'a': 0, 'b': 15},
    'feature18': {'fn': 'log', 'a': 0, 'b': 5},
    'feature19': {'fn': 'none', 'a': 0, 'b': 0},
    'feature20': {'fn': 'none', 'a': 0, 'b': 50},
    'feature21': {'fn': 'none', 'a': 0, 'b': 0},
    'feature22': {'fn': 'none', 'a': 0, 'b': 0},
    'feature23': {'fn': 'log', 'a': 32, 'b': 0},
    'feature24': {'fn': 'none', 'a': 0, 'b': 0}    
}

# %%
def data_tune(df, tuner):
    df_out = df.copy()
    for column, func in tuner.items():
        # print(column)
        # print(df_out[column].min())
        func_type = func['fn']
        a = func['a']        
        b = func['b']  
        # print(a, b)
        df_out[column] = df_out[column].apply(tune_function(func_type, a=a, b=b))
        
    return df_out

# %%
tuner = {"target0": tuner0, 
         "target1": tuner1}

data = {}
val_data = {}
for tg in TARGETS:    
    data[tg] = data_tune(X_tr, tuner[tg])
    val_data[tg] = data_tune(X_val, tuner[tg])

# %% [markdown]
# ## Нормализация

# %%
from sklearn.preprocessing import StandardScaler
import pickle

# %%
scalers = {}
for tg in TARGETS:    
    std_scaler = StandardScaler()
    std_scaler.fit(data[tg][FTS])
    data[tg][FTS] = std_scaler.transform(data[tg][FTS])
    val_data[tg][FTS] = std_scaler.transform(val_data[tg][FTS])
    
    scalers[tg] = std_scaler
    with open(f'scaler_{tg}.pickle', 'wb') as f:
        pickle.dump(std_scaler, f)

# %% [markdown]
# ## Модель

# %%
from sklearn.neural_network import MLPRegressor

# %%
data[tg][FTS].columns
# Out:
# Index(['feature0', 'feature1', 'feature10', 'feature11', 'feature12',
#        'feature13', 'feature14', 'feature15', 'feature16', 'feature17',
#        'feature18', 'feature19', 'feature2', 'feature20', 'feature21',
#        'feature22', 'feature23', 'feature24', 'feature3', 'feature5',
#        'feature6', 'feature7', 'feature8', 'feature9', 'gas'],
#       dtype='object')

# %%
val_data[tg][FTS].columns
# Out:
# Index(['feature0', 'feature1', 'feature10', 'feature11', 'feature12',
#        'feature13', 'feature14', 'feature15', 'feature16', 'feature17',
#        'feature18', 'feature19', 'feature2', 'feature20', 'feature21',
#        'feature22', 'feature23', 'feature24', 'feature3', 'feature5',
#        'feature6', 'feature7', 'feature8', 'feature9', 'gas'],
#       dtype='object')

# %%
y_tr[tg]
# Out:
# 32437      6.591908
# 3862      32.869708
# 142669    52.239636
# 82407      1.844760
# 148010     4.921912
#             ...
# 119879     4.189427
# 103694    37.123909
# 131932     4.369440
# 146867    41.967148
# 121958     6.730656
# Name: target1, Length: 76708, dtype: float64

# %%
y_tr
# Out:
#           target0    target1
# 32437   31.802060   6.591908
# 3862    73.901540  32.869708
# 142669  82.801944  52.239636
# 82407   22.129998   1.844760
# 148010  27.839774   4.921912
# ...           ...        ...
# 119879  23.377460   4.189427
# 103694  75.559708  37.123909
# 131932  23.061055   4.369440
# 146867  71.048091  41.967148
# 121958  27.900239   6.730656
#
# [76708 rows x 2 columns]

# %%
y_val
# Out:
#           target0    target1
# 37090   78.808773  44.337961
# 61708   73.675072  36.809781
# 56423   86.550986  52.653176
# 17732   80.526145  51.910781
# 62874   76.246480  64.766980
# ...           ...        ...
# 53683   22.579341   2.861112
# 132894  88.243660  52.671246
# 33184   24.461949   7.425830
# 130623  20.666541   1.510098
# 94579   28.461323   3.670957
#
# [76709 rows x 2 columns]

# %%
# %%time
models = {}
tr_preds = {}
val_preds = {}

for tg in TARGETS:
    print(f"{tg}", "=" * 10)
    mlp = MLPRegressor(hidden_layer_sizes=(26, 1024, 512, 256), random_state=RS, verbose=True, n_iter_no_change=50, tol=0.00005, max_iter=300, warm_start=True)    
    mlp.fit(data[tg][FTS], y_tr[tg]) 

    tr_preds[tg] = mlp.predict(data[tg][FTS])
    val_preds[tg] = mlp.predict(val_data[tg][FTS])
    
    with open(f'tune_mini_{tg}.pickle', 'wb') as f:
        pickle.dump(mlp, f)

    models[tg] = mlp
    
    print(f"MAPE (train {tg}): {mean_absolute_percentage_error(y_tr[tg], tr_preds[tg]) * 100:.3f} %")
    print(f"MAPE (val {tg}): {mean_absolute_percentage_error(y_val[tg], val_preds[tg]) * 100:.3f} %")
# Out:
# target0 ==========
# Iteration 1, loss = 47.77065282
# Iteration 2, loss = 0.69333168
# Iteration 3, loss = 0.39806794
# Iteration 4, loss = 0.30512106
# Iteration 5, loss = 0.25276489
# Iteration 6, loss = 0.23942497
# Iteration 7, loss = 0.21972058
# Iteration 8, loss = 0.19598012
# Iteration 9, loss = 0.18105652
# Iteration 10, loss = 0.18752838
# Iteration 11, loss = 0.17367579
# Iteration 12, loss = 0.13383710
# Iteration 13, loss = 0.14485145
# Iteration 14, loss = 0.16575252
# Iteration 15, loss = 0.14811094
# Iteration 16, loss = 0.11699339
# Iteration 17, loss = 0.11909832
# Iteration 18, loss = 0.13106994
# Iteration 19, loss = 0.12204702
# Iteration 20, loss = 0.09683883
# Iteration 21, loss = 0.10061622
# Iteration 22, loss = 0.10384789
# Iteration 23, loss = 0.11080918
# Iteration 24, loss = 0.08712971
# Iteration 25, loss = 0.09457540
# Iteration 26, loss = 0.08961861
# Iteration 27, loss = 0.10556569
# Iteration 28, loss = 0.07471263
# Iteration 29, loss = 0.09900719
# Iteration 30, loss = 0.07733388
# Iteration 31, loss = 0.06955450
# Iteration 32, loss = 0.08656259
# Iteration 33, loss = 0.08586541
# Iteration 34, loss = 0.07752372
# Iteration 35, loss = 0.05748320
# Iteration 36, loss = 0.07302036
# Iteration 37, loss = 0.08655264
# Iteration 38, loss = 0.06740084
# Iteration 39, loss = 0.06432575
# Iteration 40, loss = 0.06658385
# Iteration 41, loss = 0.06774952
# Iteration 42, loss = 0.06561768
# Iteration 43, loss = 0.06538182
# Iteration 44, loss = 0.07476215
# Iteration 45, loss = 0.05418279
# Iteration 46, loss = 0.08263348
# Iteration 47, loss = 0.05139541
# Iteration 48, loss = 0.06035189
# Iteration 49, loss = 0.05796014
# Iteration 50, loss = 0.06070276
# Iteration 51, loss = 0.05901277
# Iteration 52, loss = 0.06275504
# Iteration 53, loss = 0.05345191
# Iteration 54, loss = 0.06109913
# Iteration 55, loss = 0.05610876
# Iteration 56, loss = 0.05291400
# Iteration 57, loss = 0.05702175
# Iteration 58, loss = 0.06264446
# Iteration 59, loss = 0.04616257
# Iteration 60, loss = 0.06300706
# Iteration 61, loss = 0.04720718
# Iteration 62, loss = 0.04790908
# Iteration 63, loss = 0.06118476
# Iteration 64, loss = 0.04494811
# Iteration 65, loss = 0.04744691
# Iteration 66, loss = 0.05677522
# Iteration 67, loss = 0.05433849
# Iteration 68, loss = 0.04902193
# Iteration 69, loss = 0.05448861
# Iteration 70, loss = 0.04647433
# Iteration 71, loss = 0.04718004
# Iteration 72, loss = 0.04794294
# Iteration 73, loss = 0.05216565
# Iteration 74, loss = 0.04915378
# Iteration 75, loss = 0.04704561
# Iteration 76, loss = 0.04157381
# Iteration 77, loss = 0.05066482
# Iteration 78, loss = 0.04736025
# Iteration 79, loss = 0.04149703
# Iteration 80, loss = 0.05200781
# Iteration 81, loss = 0.04112839
# Iteration 82, loss = 0.04735757
# Iteration 83, loss = 0.04502408
# Iteration 84, loss = 0.04600908
# Iteration 85, loss = 0.05055675
# Iteration 86, loss = 0.03651252
# Iteration 87, loss = 0.04567862
# Iteration 88, loss = 0.05225985
# Iteration 89, loss = 0.03690240
# Iteration 90, loss = 0.04351619
# Iteration 91, loss = 0.04329850
# Iteration 92, loss = 0.04101960
# Iteration 93, loss = 0.04760306
# Iteration 94, loss = 0.04848710
# Iteration 95, loss = 0.04122609
# Iteration 96, loss = 0.04382833
# Iteration 97, loss = 0.04258328
# Iteration 98, loss = 0.03888609
# Iteration 99, loss = 0.04622589
# Iteration 100, loss = 0.03997830
# Iteration 101, loss = 0.03539884
# Iteration 102, loss = 0.04081237
# Iteration 103, loss = 0.04769087
# Iteration 104, loss = 0.03584610
# Iteration 105, loss = 0.04027442
# Iteration 106, loss = 0.04301804
# Iteration 107, loss = 0.03998859
# Iteration 108, loss = 0.04347635
# Iteration 109, loss = 0.03525475
# Iteration 110, loss = 0.04968908
# Iteration 111, loss = 0.03195286
# Iteration 112, loss = 0.03892011
# Iteration 113, loss = 0.03969535
# Iteration 114, loss = 0.03939735
# Iteration 115, loss = 0.03880695
# Iteration 116, loss = 0.03684609
# Iteration 117, loss = 0.04010354
# Iteration 118, loss = 0.03529585
# Iteration 119, loss = 0.04829966
# Iteration 120, loss = 0.03960637
# Iteration 121, loss = 0.03585602
# Iteration 122, loss = 0.03176529
# Iteration 123, loss = 0.04046923
# Iteration 124, loss = 0.03605797
# Iteration 125, loss = 0.03912192
# Iteration 126, loss = 0.03567930
# Iteration 127, loss = 0.03575580
# Iteration 128, loss = 0.03848817
# Iteration 129, loss = 0.03384063
# Iteration 130, loss = 0.03816845
# Iteration 131, loss = 0.03496575
# Iteration 132, loss = 0.03383454
# Iteration 133, loss = 0.04041993
# Iteration 134, loss = 0.02953398
# Iteration 135, loss = 0.04474049
# Iteration 136, loss = 0.03070487
# Iteration 137, loss = 0.03420066
# Iteration 138, loss = 0.03409218
# Iteration 139, loss = 0.03703959
# Iteration 140, loss = 0.03383131
# Iteration 141, loss = 0.04108890
# Iteration 142, loss = 0.02814742
# Iteration 143, loss = 0.03107846
# Iteration 144, loss = 0.03735375
# Iteration 145, loss = 0.03895817
# Iteration 146, loss = 0.03603181
# Iteration 147, loss = 0.02831227
# Iteration 148, loss = 0.03403677
# Iteration 149, loss = 0.03152702
# Iteration 150, loss = 0.03112930
# Iteration 151, loss = 0.03840675
# Iteration 152, loss = 0.02800964
# Iteration 153, loss = 0.03353010
# Iteration 154, loss = 0.03067362
# Iteration 155, loss = 0.03485279
# Iteration 156, loss = 0.03087846
# Iteration 157, loss = 0.03081234
# Iteration 158, loss = 0.03670546
# Iteration 159, loss = 0.02756416
# Iteration 160, loss = 0.02792042
# Iteration 161, loss = 0.03513073
# Iteration 162, loss = 0.02784141
# Iteration 163, loss = 0.03261079
# Iteration 164, loss = 0.03294008
# Iteration 165, loss = 0.03214408
# Iteration 166, loss = 0.02703065
# Iteration 167, loss = 0.02936077
# Iteration 168, loss = 0.03645029
# Iteration 169, loss = 0.03045568
# Iteration 170, loss = 0.02772159
# Iteration 171, loss = 0.02954244
# Iteration 172, loss = 0.03064646
# Iteration 173, loss = 0.02674950
# Iteration 174, loss = 0.03916384
# Iteration 175, loss = 0.02695292
# Iteration 176, loss = 0.02729639
# Iteration 177, loss = 0.02605205
# Iteration 178, loss = 0.02962360
# Iteration 179, loss = 0.02870966
# Iteration 180, loss = 0.03290228
# Iteration 181, loss = 0.02718585
# Iteration 182, loss = 0.02500846
# Iteration 183, loss = 0.03643893
# Iteration 184, loss = 0.02869947
# Iteration 185, loss = 0.02476550
# Iteration 186, loss = 0.02604482
# Iteration 187, loss = 0.02572825
# Iteration 188, loss = 0.02876052
# Iteration 189, loss = 0.02661011
# Iteration 190, loss = 0.02491550
# Iteration 191, loss = 0.03323109
# Iteration 192, loss = 0.02510275
# Iteration 193, loss = 0.02989125
# Iteration 194, loss = 0.02661779
# Iteration 195, loss = 0.02930987
# Iteration 196, loss = 0.02363403
# Iteration 197, loss = 0.02715081
# Iteration 198, loss = 0.02700313
# Iteration 199, loss = 0.02402805
# Iteration 200, loss = 0.02501461
# Iteration 201, loss = 0.02863419
# Iteration 202, loss = 0.02175295
# Iteration 203, loss = 0.02715448
# Iteration 204, loss = 0.02320006
# Iteration 205, loss = 0.02748550
# Iteration 206, loss = 0.02380123
# Iteration 207, loss = 0.02572381
# Iteration 208, loss = 0.02698068
# Iteration 209, loss = 0.02127171
# Iteration 210, loss = 0.02384665
# Iteration 211, loss = 0.02525312
# Iteration 212, loss = 0.02188104
# Iteration 213, loss = 0.02284153
# Iteration 214, loss = 0.02453047
# Iteration 215, loss = 0.02296333
# Iteration 216, loss = 0.02258450
# Iteration 217, loss = 0.02560435
# Iteration 218, loss = 0.02690308
# Iteration 219, loss = 0.02174307
# Iteration 220, loss = 0.02149240
# Iteration 221, loss = 0.01936633
# Iteration 222, loss = 0.02961898
# Iteration 223, loss = 0.02008714
# Iteration 224, loss = 0.02251709
# Iteration 225, loss = 0.02448136
# Iteration 226, loss = 0.02236817
# Iteration 227, loss = 0.02267496
# Iteration 228, loss = 0.02372128
# Iteration 229, loss = 0.01968239
# Iteration 230, loss = 0.02083939
# Iteration 231, loss = 0.02304366
# Iteration 232, loss = 0.02944003
# Iteration 233, loss = 0.02246116
# Iteration 234, loss = 0.01952991
# Iteration 235, loss = 0.01985151
# Iteration 236, loss = 0.02569079
# Iteration 237, loss = 0.01833948
# Iteration 238, loss = 0.02139103
# Iteration 239, loss = 0.01953214
# Iteration 240, loss = 0.01766113
# Iteration 241, loss = 0.02226611
# Iteration 242, loss = 0.01639006
# Iteration 243, loss = 0.02244621
# Iteration 244, loss = 0.01966236
# Iteration 245, loss = 0.02085269
# Iteration 246, loss = 0.01746727
# Iteration 247, loss = 0.01941422
# Iteration 248, loss = 0.03271327
# Iteration 249, loss = 0.01417869
# Iteration 250, loss = 0.01436276
# Iteration 251, loss = 0.01713058
# Iteration 252, loss = 0.02566242
# Iteration 253, loss = 0.01926689
# Iteration 254, loss = 0.02213130
# Iteration 255, loss = 0.01728347
# Iteration 256, loss = 0.01420077
# Iteration 257, loss = 0.02041894
# Iteration 258, loss = 0.01794567
# Iteration 259, loss = 0.01977184
# Iteration 260, loss = 0.01954674
# Iteration 261, loss = 0.02040071
# Iteration 262, loss = 0.01861339
# Iteration 263, loss = 0.02016156
# Iteration 264, loss = 0.01674262
# Iteration 265, loss = 0.01735127
# Iteration 266, loss = 0.01649612
# Iteration 267, loss = 0.01992326
# Iteration 268, loss = 0.01805459
# Iteration 269, loss = 0.01797368
# Iteration 270, loss = 0.01893459
# Iteration 271, loss = 0.01832713
# Iteration 272, loss = 0.01906014
# Iteration 273, loss = 0.01818803
# Iteration 274, loss = 0.01641215
# Iteration 275, loss = 0.01942956
# Iteration 276, loss = 0.01710500
# Iteration 277, loss = 0.01823368
# Iteration 278, loss = 0.01870398
# Iteration 279, loss = 0.01575996
# Iteration 280, loss = 0.02000119
# Training loss did not improve more than tol=0.000050 for 30 consecutive epochs. Stopping.
# MAPE (train target0): 0.329 %
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:19
#
# NameError: name 'val_pred' is not defined

# %%
print(f"MAPE (val {tg}): {mean_absolute_percentage_error(y_val[tg], val_preds[tg]) * 100:.3f} %")
# Out:
# MAPE (val target0): 0.349 %

# %%
tg = 'target1'
print(f"{tg}", "=" * 10)
mlp = MLPRegressor(hidden_layer_sizes=(26, 1024, 512, 256), random_state=RS, verbose=True, n_iter_no_change=50, tol=0.00005, max_iter=300, warm_start=True)    
mlp.fit(data[tg][FTS], y_tr[tg]) 

tr_preds[tg] = mlp.predict(data[tg][FTS])
val_preds[tg] = mlp.predict(val_data[tg][FTS])

with open(f'tune_mini_{tg}.pickle', 'wb') as f:
    pickle.dump(mlp, f)

models[tg] = mlp

print(f"MAPE (train {tg}): {mean_absolute_percentage_error(y_tr[tg], tr_preds[tg]) * 100:.3f} %")
print(f"MAPE (val {tg}): {mean_absolute_percentage_error(y_val[tg], val_preds[tg]) * 100:.3f} %")
# Out:
# target1 ==========
# Iteration 1, loss = 16.36847566
# Iteration 2, loss = 0.49065673
# Iteration 3, loss = 0.39879318
# Iteration 4, loss = 0.35788786
# Iteration 5, loss = 0.34153834
# Iteration 6, loss = 0.29013127
# Iteration 7, loss = 0.29354053
# Iteration 8, loss = 0.26708897
# Iteration 9, loss = 0.25362942
# Iteration 10, loss = 0.26261696
# Iteration 11, loss = 0.24445817
# Iteration 12, loss = 0.25543328
# Iteration 13, loss = 0.23305379
# Iteration 14, loss = 0.20979912
# Iteration 15, loss = 0.21528445
# Iteration 16, loss = 0.22679329
# Iteration 17, loss = 0.23167875
# Iteration 18, loss = 0.23721660
# Iteration 19, loss = 0.20784882
# Iteration 20, loss = 0.22737183
# Iteration 21, loss = 0.22540192
# Iteration 22, loss = 0.19194393
# Iteration 23, loss = 0.19435074
# Iteration 24, loss = 0.22590799
# Iteration 25, loss = 0.19299731
# Iteration 26, loss = 0.19773706
# Iteration 27, loss = 0.20661440
# Iteration 28, loss = 0.18856971
# Iteration 29, loss = 0.19470892
# Iteration 30, loss = 0.20216475
# Iteration 31, loss = 0.19538391
# Iteration 32, loss = 0.18829808
# Iteration 33, loss = 0.18906019
# Iteration 34, loss = 0.19183174
# Iteration 35, loss = 0.18067933
# Iteration 36, loss = 0.20455417
# Iteration 37, loss = 0.18397469
# Iteration 38, loss = 0.18130860
# Iteration 39, loss = 0.18862841
# Iteration 40, loss = 0.18600710
# Iteration 41, loss = 0.17383838
# Iteration 42, loss = 0.18519759
# Iteration 43, loss = 0.18346650
# Iteration 44, loss = 0.17763428
# Iteration 45, loss = 0.17521502
# Iteration 46, loss = 0.17868201
# Iteration 47, loss = 0.18169509
# Iteration 48, loss = 0.17311682
# Iteration 49, loss = 0.17196562
# Iteration 50, loss = 0.17855109
# Iteration 51, loss = 0.17879518
# Iteration 52, loss = 0.16413940
# Iteration 53, loss = 0.17338341
# Iteration 54, loss = 0.17021755
# Iteration 55, loss = 0.16322715
# Iteration 56, loss = 0.17157074
# Iteration 57, loss = 0.16413899
# Iteration 58, loss = 0.16455732
# Iteration 59, loss = 0.18272254
# Iteration 60, loss = 0.17304409
# Iteration 61, loss = 0.15836658
# Iteration 62, loss = 0.16827868
# Iteration 63, loss = 0.15782050
# Iteration 64, loss = 0.15906119
# Iteration 65, loss = 0.16382217
# Iteration 66, loss = 0.15589768
# Iteration 67, loss = 0.16203511
# Iteration 68, loss = 0.17542395
# Iteration 69, loss = 0.15795518
# Iteration 70, loss = 0.16555355
# Iteration 71, loss = 0.16326765
# Iteration 72, loss = 0.15980675
# Iteration 73, loss = 0.16597175
# Iteration 74, loss = 0.15864036
# Iteration 75, loss = 0.15761698
# Iteration 76, loss = 0.15597473
# Iteration 77, loss = 0.15831970
# Iteration 78, loss = 0.16375415
# Iteration 79, loss = 0.16119264
# Iteration 80, loss = 0.16565060
# Iteration 81, loss = 0.15316856
# Iteration 82, loss = 0.15823024
# Iteration 83, loss = 0.15322650
# Iteration 84, loss = 0.15869898
# Iteration 85, loss = 0.14866889
# Iteration 86, loss = 0.16230424
# Iteration 87, loss = 0.15936683
# Iteration 88, loss = 0.15487873
# Iteration 89, loss = 0.15820703
# Iteration 90, loss = 0.15256008
# Iteration 91, loss = 0.15642950
# Iteration 92, loss = 0.16602457
# Iteration 93, loss = 0.15019734
# Iteration 94, loss = 0.15373480
# Iteration 95, loss = 0.15701672
# Iteration 96, loss = 0.16427227
# Iteration 97, loss = 0.15240458
# Iteration 98, loss = 0.15465360
# Iteration 99, loss = 0.16143313
# Iteration 100, loss = 0.15799512
# Iteration 101, loss = 0.14783615
# Iteration 102, loss = 0.14811591
# Iteration 103, loss = 0.15284163
# Iteration 104, loss = 0.14450027
# Iteration 105, loss = 0.15702277
# Iteration 106, loss = 0.15269092
# Iteration 107, loss = 0.16222999
# Iteration 108, loss = 0.14954893
# Iteration 109, loss = 0.15127470
# Iteration 110, loss = 0.15147669
# Iteration 111, loss = 0.14531423
# Iteration 112, loss = 0.15415334
# Iteration 113, loss = 0.14508592
# Iteration 114, loss = 0.15022387
# Iteration 115, loss = 0.14929154
# Iteration 116, loss = 0.14114306
# Iteration 117, loss = 0.15170063
# Iteration 118, loss = 0.14920425
# Iteration 119, loss = 0.14700066
# Iteration 120, loss = 0.14999965
# Iteration 121, loss = 0.15440274
# Iteration 122, loss = 0.14652418
# Iteration 123, loss = 0.14519474
# Iteration 124, loss = 0.15290169
# Iteration 125, loss = 0.15354173
# Iteration 126, loss = 0.14007959
# Iteration 127, loss = 0.15253596
# Iteration 128, loss = 0.15871915
# Iteration 129, loss = 0.14548625
# Iteration 130, loss = 0.14814076
# Iteration 131, loss = 0.14777491
# Iteration 132, loss = 0.14357505
# Iteration 133, loss = 0.15216968
# Iteration 134, loss = 0.14682584
# Iteration 135, loss = 0.14847244
# Iteration 136, loss = 0.15137159
# Iteration 137, loss = 0.13979824
# Iteration 138, loss = 0.14868857
# Iteration 139, loss = 0.14929685
# Iteration 140, loss = 0.14981418
# Iteration 141, loss = 0.14222880
# Iteration 142, loss = 0.14580852
# Iteration 143, loss = 0.14864084
# Iteration 144, loss = 0.14633228
# Iteration 145, loss = 0.14491672
# Iteration 146, loss = 0.14671321
# Iteration 147, loss = 0.14682224
# Iteration 148, loss = 0.14425111
# Iteration 149, loss = 0.15533350
# Iteration 150, loss = 0.14421712
# Iteration 151, loss = 0.14227175
# Iteration 152, loss = 0.14868179
# Iteration 153, loss = 0.14291848
# Iteration 154, loss = 0.14510901
# Iteration 155, loss = 0.14652420
# Iteration 156, loss = 0.14390246
# Iteration 157, loss = 0.14260465
# Iteration 158, loss = 0.15053622
# Iteration 159, loss = 0.14234291
# Iteration 160, loss = 0.14347288
# Iteration 161, loss = 0.14227658
# Iteration 162, loss = 0.14488972
# Iteration 163, loss = 0.14422536
# Iteration 164, loss = 0.14063301
# Iteration 165, loss = 0.14110780
# Iteration 166, loss = 0.13609447
# Iteration 167, loss = 0.14506477
# Iteration 168, loss = 0.15233954
# Iteration 169, loss = 0.13731120
# Iteration 170, loss = 0.14000087
# Iteration 171, loss = 0.14098084
# Iteration 172, loss = 0.14363165
# Iteration 173, loss = 0.14364738
# Iteration 174, loss = 0.14674612
# Iteration 175, loss = 0.14053631
# Iteration 176, loss = 0.13542268
# Iteration 177, loss = 0.13594283
# Iteration 178, loss = 0.13869600
# Iteration 179, loss = 0.14029414
# Iteration 180, loss = 0.13998164
# Iteration 181, loss = 0.13333965
# Iteration 182, loss = 0.14123280
# Iteration 183, loss = 0.14246825
# Iteration 184, loss = 0.13627013
# Iteration 185, loss = 0.13822843
# Iteration 186, loss = 0.14383750
# Iteration 187, loss = 0.14039248
# Iteration 188, loss = 0.14040280
# Iteration 189, loss = 0.13797368
# Iteration 190, loss = 0.14890329
# Iteration 191, loss = 0.13697359
# Iteration 192, loss = 0.13404612
# Iteration 193, loss = 0.14101920
# Iteration 194, loss = 0.14073337
# Iteration 195, loss = 0.13732314
# Iteration 196, loss = 0.14384819
# Iteration 197, loss = 0.13889426
# Iteration 198, loss = 0.13902296
# Iteration 199, loss = 0.13737826
# Iteration 200, loss = 0.14125855
# Iteration 201, loss = 0.14475712
# Iteration 202, loss = 0.13266542
# Iteration 203, loss = 0.13186461
# Iteration 204, loss = 0.13361753
# Iteration 205, loss = 0.13773268
# Iteration 206, loss = 0.14075967
# Iteration 207, loss = 0.13561813
# Iteration 208, loss = 0.13166448
# Iteration 209, loss = 0.13688075
# Iteration 210, loss = 0.13521166
# Iteration 211, loss = 0.13703296
# Iteration 212, loss = 0.13440242
# Iteration 213, loss = 0.13479798
# Iteration 214, loss = 0.13610732
# Iteration 215, loss = 0.13704799
# Iteration 216, loss = 0.13056709
# Iteration 217, loss = 0.13234010
# Iteration 218, loss = 0.13558598
# Iteration 219, loss = 0.13414914
# Iteration 220, loss = 0.13847821
# Iteration 221, loss = 0.14011757
# Iteration 222, loss = 0.14197288
# Iteration 223, loss = 0.13020929
# Iteration 224, loss = 0.13114127
# Iteration 225, loss = 0.13460598
# Iteration 226, loss = 0.13671537
# Iteration 227, loss = 0.12996291
# Iteration 228, loss = 0.13261706
# Iteration 229, loss = 0.13323237
# Iteration 230, loss = 0.13536129
# Iteration 231, loss = 0.13309069
# Iteration 232, loss = 0.13777306
# Iteration 233, loss = 0.13165663
# Iteration 234, loss = 0.13392076
# Iteration 235, loss = 0.13464973
# Iteration 236, loss = 0.13123728
# Iteration 237, loss = 0.12829877
# Iteration 238, loss = 0.13356830
# Iteration 239, loss = 0.13354843
# Iteration 240, loss = 0.13909945
# Iteration 241, loss = 0.13471489
# Iteration 242, loss = 0.13177010
# Iteration 243, loss = 0.13610902
# Iteration 244, loss = 0.13156623
# Iteration 245, loss = 0.13105531
# Iteration 246, loss = 0.13384389
# Iteration 247, loss = 0.13080479
# Iteration 248, loss = 0.13180262
# Iteration 249, loss = 0.13039891
# Iteration 250, loss = 0.12692217
# Iteration 251, loss = 0.12789534
# Iteration 252, loss = 0.12893116
# Iteration 253, loss = 0.13388354
# Iteration 254, loss = 0.13304430
# Iteration 255, loss = 0.13151103
# Iteration 256, loss = 0.12699111
# Iteration 257, loss = 0.13138594
# Iteration 258, loss = 0.13969851
# Iteration 259, loss = 0.12694515
# Iteration 260, loss = 0.12704830
# Iteration 261, loss = 0.12815310
# Iteration 262, loss = 0.13040751
# Iteration 263, loss = 0.13310996
# Iteration 264, loss = 0.13330033
# Iteration 265, loss = 0.13258686
# Iteration 266, loss = 0.12620366
# Iteration 267, loss = 0.13221178
# Iteration 268, loss = 0.13114469
# Iteration 269, loss = 0.12850609
# Iteration 270, loss = 0.12793582
# Iteration 271, loss = 0.12999076
# Iteration 272, loss = 0.12198758
# Iteration 273, loss = 0.13111589
# Iteration 274, loss = 0.13247788
# Iteration 275, loss = 0.13603591
# Iteration 276, loss = 0.12679457
# Iteration 277, loss = 0.12673757
# Iteration 278, loss = 0.12806178
# Iteration 279, loss = 0.12553651
# Iteration 280, loss = 0.12842883
# Iteration 281, loss = 0.12572587
# Iteration 282, loss = 0.12280823
# Iteration 283, loss = 0.12587421
# Iteration 284, loss = 0.12142723
# Iteration 285, loss = 0.12764809
# Iteration 286, loss = 0.12275330
# Iteration 287, loss = 0.12815303
# Iteration 288, loss = 0.12400304
# Iteration 289, loss = 0.12459787
# Iteration 290, loss = 0.12278632
# Iteration 291, loss = 0.13112231
# Iteration 292, loss = 0.12198627
# Iteration 293, loss = 0.12992685
# Iteration 294, loss = 0.12634246
# Iteration 295, loss = 0.12370793
# Iteration 296, loss = 0.12554294
# Iteration 297, loss = 0.12635055
# Iteration 298, loss = 0.12667370
# Iteration 299, loss = 0.12251810
# Iteration 300, loss = 0.12208761
# D:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MAPE (train target1): 1.333 %
# MAPE (val target1): 1.429 %

# %%
# with open(f'bad_tune_mini_{tg}.pickle', 'wb') as f:
#     pickle.dump(mlp, f)

# %%
# X_tr, X_val, y_tr, y_val = train_test_split(train[FTS], train[TARGETS], train_size=0.5, random_state=RS)  # разбивка на трейн и тест

# %%
# print(f"MAPE (train): {mean_absolute_percentage_error(y_tr, tr_preds) * 100:.3f} %")
# print(f"MAPE (val): {mean_absolute_percentage_error(y_val, val_preds) * 100:.3f} %")

# %% [markdown]
# ## Полное обучение

# %%
tuner = {"target0": tuner0, 
         "target1": tuner1}

data = {}
val_data = {}
for tg in TARGETS:    
    data[tg] = data_tune(train, tuner[tg])

# %%
scalers = {}
for tg in TARGETS:    
    std_scaler = StandardScaler()
    std_scaler.fit(data[tg][FTS])
    data[tg][FTS] = std_scaler.transform(data[tg][FTS])
    
    scalers[tg] = std_scaler
    with open(f'full_scaler_{tg}.pickle', 'wb') as f:
        pickle.dump(std_scaler, f)

# %%
# %%time
models = {}
tr_preds = {}
val_preds = {}

for tg in TARGETS:
    print(f"{tg}", "=" * 10)
    mlp = MLPRegressor(hidden_layer_sizes=(26, 1024, 512, 256), random_state=RS, verbose=True, n_iter_no_change=50, tol=0.00005, max_iter=300, warm_start=True)    
    mlp.fit(data[tg][FTS], y_tr[tg]) 

    tr_preds[tg] = mlp.predict(data[tg][FTS])
    # val_pred[tg] = mlp.predict(val_data[tg])
    
    with open(f'tune_full_{tg}.pickle', 'wb') as f:
        pickle.dump(mlp, f)

    models[tg] = mlp
    
    print(f"MAPE (train {tg}): {mean_absolute_percentage_error(y_tr[tg], tr_preds[tg]) * 100:.3f} %")
    # print(f"MAPE (val {tg}): {mean_absolute_percentage_error(y_val, val_pred[tg]) * 100:.3f} %")
# Out:
# target0 ==========
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:8
#
# File D:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:747, in BaseMultilayerPerceptron.fit(self, X, y)
#     729 """Fit the model to data matrix X and target(s) y.
#     730
#     731 Parameters
#    (...)
#     743     Returns a trained MLP model.
#     744 """
#     745 self._validate_params()
# --> 747 return self._fit(X, y, incremental=False)
#
# File D:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:437, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     430     raise ValueError(
#     431         "hidden_layer_sizes must be > 0, got %s." % hidden_layer_sizes
#     432     )
#     433 first_pass = not hasattr(self, "coefs_") or (
#     434     not self.warm_start and not incremental
#     435 )
# --> 437 X, y = self._validate_input(X, y, incremental, reset=first_pass)
#     439 n_samples, n_features = X.shape
#     441 # Ensure y is 2D
#
# File D:\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1607, in MLPRegressor._validate_input(self, X, y, incremental, reset)
#    1606 def _validate_input(self, X, y, incremental, reset):
# -> 1607     X, y = self._validate_data(
#    1608         X,
#    1609         y,
#    1610         accept_sparse=["csr", "csc"],
#    1611         multi_output=True,
#    1612         y_numeric=True,
#    1613         dtype=(np.float64, np.float32),
#    1614         reset=reset,
#    1615     )
#    1616     if y.ndim == 2 and y.shape[1] == 1:
#    1617         y = column_or_1d(y, warn=True)
#
# File D:\anaconda3\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\anaconda3\lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File D:\anaconda3\lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File D:\anaconda3\lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:1998, in NDFrame.__array__(self, dtype)
#    1996 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997     values = self._values
# -> 1998     arr = np.asarray(values, dtype=dtype)
#    1999     if (
#    2000         astype_is_view(values.dtype, arr.dtype)
#    2001         and using_copy_on_write()
#    2002         and self._mgr.is_single_block
#    2003     ):
#    2004         # Check if both conversions can be done without a copy
#    2005         if astype_is_view(self.dtypes.iloc[0], values.dtype) and astype_is_view(
#    2006             values.dtype, arr.dtype
#    2007         ):
#
# ValueError: could not convert string to float: 'gas1'
